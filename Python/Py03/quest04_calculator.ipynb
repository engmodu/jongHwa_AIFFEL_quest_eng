# %% [markdown]
# <a href="https://colab.research.google.com/github/woooorking/AIFFEL_quest_eng/blob/main/Python/Py03/quest04_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #QUEST 04 파이썬을 사용하여 간단한 계산기 프로그램 만들기

# %%
while True: #반복해서 계산할 수 있도록 함

    # 첫 번째 정수 입력
    while True:
        try:
            num1 = int(input("첫 번째 숫자를 입력하세요: "))
            break  # 숫자가 잘 입력되면 아래로 내려감
        except ValueError:
            print("잘못된 입력입니다. 정수를 입력해주세요.") # 잘못 입력하면 에러 띄우고 다시 입력받음

    # 연산자 입력 받기
    operator = input("연산자를 입력하세요 (+, -, *, /, **): ")

    # 두 번째 정수 입력
    while True:
        try:
            num2 = int(input("두 번째 숫자를 입력하세요: "))
            break
        except ValueError:
            print("잘못된 입력입니다. 정수를 입력해주세요.") # 잘못 입력하면 에러 띄우고 다시 입력받음

    # 입력받은 연산자에 따라 계산하기
    if operator == "+":
        result = num1 + num2
        print(f"결과: {result}") #num1+num2한 결과를 result라는 상자에 넣고 보여주는거


    elif operator == "-":
        result = num1 - num2
        print(f"결과: {result}")

    elif operator == "*":
        result = num1 * num2
        print(f"결과: {result}")

    elif operator == "/":
        try:
            result = num1 / num2
            print(f"결과: {result}")
        except ZeroDivisionError: # 0으로 나누면 ZeroDivisionError 오류 뜨게하기
            print("오류: 0으로 나눌 수 없습니다.")

    elif operator == "**":
        import math
        result = math.pow(num1, num2) #pow으로 num1을 num2번 곱해주고 그 결과 담기
        print(f"결과: {result}")

    else:
        print("지원하지 않는 연산자입니다.") #위에 적은 연산자들 말고 다른거 넣었을때 뜨는 오류 메세지

    #계산기 계속할지 물어보기

    cont = input("계속 계산하기 (y/n): ")
    if cont == "n": #답변으로 n  no!를 입력하면
        print("계산기 종료.")
        break  #'n'을 입력하면 while문이 끝나고 종료됨.
# Out:
# 첫 번째 숫자를 입력하세요: 4
# 연산자를 입력하세요 (+, -, *, /, **): /
# 두 번째 숫자를 입력하세요: 0
# 오류: 0으로 나눌 수 없습니다.
# 계속 계산하기 (y/n): n
# 계산기 종료.
